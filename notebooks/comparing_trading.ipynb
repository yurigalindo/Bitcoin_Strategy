# %%
import sys
sys.path.append("..")
from source.utils.backtest import BacktestTradeModels
from source.models.exit_strategy import TrailLoss
from source.models.traditional_trading import BuyAtSellAt
from source.models.central_model import TradingModel
from source.models.allocation_models import AllInAllOut

# %%
backtest = BacktestTradeModels("../data/BTC-USD.csv",start_date='2020-09-20')
backtest(TradingModel(TrailLoss(0.2),AllInAllOut()))
# Out:
# 235.7090683325641

# %%
backtest = BacktestTradeModels("../data/BTC-USD.csv",start_date='2020-09-20')
backtest(TradingModel(TrailLoss(0.2,threshold=10),AllInAllOut()))
# Out:
# 857.3677390373743

# %%
backtest = BacktestTradeModels("../data/BTC-USD.csv",start_date='2020-09-20')
backtest(TradingModel(BuyAtSellAt(),AllInAllOut()))
# Out:
# 1584.9181375376995
