# %%
import sys
sys.path.append("..")
from source.backtest import BacktestTradeModels
from source.models.exit_strategy import TrailLoss
from source.models.traditional_trading import BuyAtSellAt

# %%
backtest = BacktestTradeModels("../data/BTC-USD.csv",start_date='2020-09-20')
backtest(TrailLoss(0.2,1))
# Out:
# 235.7090683325641

# %%
backtest = BacktestTradeModels("../data/BTC-USD.csv",start_date='2020-09-20')
backtest(TrailLoss(0.15,1))
# Out:
# 261.7855857369185

# %%
backtest = BacktestTradeModels("../data/BTC-USD.csv",start_date='2020-09-20')
backtest(TrailLoss(0.15,1,threshold=1.5))
# Out:
# 544.184054276198

# %%
backtest = BacktestTradeModels("../data/BTC-USD.csv",start_date='2020-09-20')
backtest(TrailLoss(0.15,1,threshold=2))
# Out:
# 544.184054276198

# %%
backtest = BacktestTradeModels("../data/BTC-USD.csv",start_date='2020-09-20')
backtest(TrailLoss(0.15,1,threshold=10))
# Out:
# 943.542232457613

# %%
backtest = BacktestTradeModels("../data/BTC-USD.csv",start_date='2020-07-20')
backtest(BuyAtSellAt())
# Out:
# 1914.1856246528719
